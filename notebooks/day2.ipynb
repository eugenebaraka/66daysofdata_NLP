# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Frequency distribution and common words in a text

freq1 = FreqDist(text1)
freq1.plot(50, cumulative = True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
# find hapaxes (words the occur only once in a text)
freq1.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
# A collocation: is a sequence of words that occur together unusually often
# bigram: word pair

bigram = bigrams(["more", "is", "said", "than", "done"])
print(next(bigram))
print(next(bigram))
print(next(bigram))
print(next(bigram))

# collocations will be the bigrams that occur in the text more often
# Out:
# ('more', 'is')
# ('is', 'said')
# ('said', 'than')
# ('than', 'done')

# %%
text3.collocations()
# Out:
# said unto; pray thee; thou shalt; thou hast; thy seed; years old;
# spake unto; thou art; LORD God; every living; God hath; begat sons;
# seven years; shalt thou; little ones; living creature; creeping thing;
# savoury meat; thirty years; every beast

# %%
sorted(w for w in set(text7) if "-" in w and "index" in w)
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %%
for token in sent1:
    if token.islower():
        print(token, "is a lower case word")
    elif token.istitle():
        print(token, "is a titlecase word")
    else:
        print(token, "is a punctuation")
# Out:
# Call is a titlecase word
# me is a lower case word
# Ishmael is a titlecase word
# . is a punctuation

# %%
tricky = sorted(w for w in set(text1) if "cie" in w or "cei" in w)
for word in tricky:
    print(word, end=", ")
# Out:
# Glacier, Receiving, Science, Sciences, Societies, Society, agencies, ancient, ancientest, ceiling, conceit, conceited, conceits, conceivable, conceive, conceived, conceives, conscience, consciences, conscientious, conscientiously, contingencies, deceitfully, deceitfulness, deceits, deceive, deceived, deceiving, deficiencies, deficiency, efficiency, efficient, emergencies, fancied, fancies, glacier, insufficient, intricacies, omniscient, omnisciently, perceive, perceived, perceiving, potencies, prescience, prescient, prophecies, receive, received, receives, receiving, science, sciences, scientific, society, species, sufficient, sufficiently, unscientific, vacancies,

# %%
# shortcomings of machine translation: misinterprets grammatical structure...
# Text alignment: if we have a huge text in two language and a bilingual dictionary, 
## we can automatically pair up sentences, and build a model that can be used to translate new text
